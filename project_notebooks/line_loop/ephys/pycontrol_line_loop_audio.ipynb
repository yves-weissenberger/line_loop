# %%
  
#import pyb
import math
import matplotlib.pyplot as plt
#from . import hardware as hw

_sine_len = 100 # Number of points in sine wave.
_sine_buf = bytearray([128+int(127*math.sin(2*math.pi*i/_sine_len)) for i in range(_sine_len)])
_sqr_buf = bytearray([255,0])
_click_buf = bytearray([255,0,255,255,0,0]+4*[255]+4*[0]+8*[255]+8*[0]
                       +16*[255]+16*[0]+32*[255]+32*[0]+[128])
_off_buf = bytearray([128])

# Audio output ----------------------------------------------------------------

class Audio_output(hw.IO_object):
    def __init__(self, channel=1):
        assert channel in [1,2], '! Channel number invalid, must be 1 or 2.'
        self._DAC = pyb.DAC(channel) 
        self._timer = pyb.Timer(hw.available_timers.pop())
        self._func = None # Function currently being used for sweeped sound (sine, square or noise)
        self._freq = 0
        self._freq_ind = 0
        self.off()
        hw.assign_ID(self)

    # User functions

    def off(self):
            self._DAC.write_timed(_off_buf, 10000, mode=pyb.DAC.NORMAL)
            self._timer.deinit()
            self._playing = False

    def sine(self, freq):  # Play a sine wave tone at the specified frequency.
        self._DAC.write_timed(_sine_buf, freq*_sine_len, mode=pyb.DAC.CIRCULAR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c8c6fadc8628> in <module>
#      13 # Audio output ----------------------------------------------------------------
#      14
# ---> 15 class Audio_output(hw.IO_object):
#      16     def __init__(self, channel=1):
#      17         assert channel in [1,2], '! Channel number invalid, must be 1 or 2.'
#
# NameError: name 'hw' is not defined

# %%
_sine_len = 100 # Number of points in sine wave.
_sine_buf = [128+int(127*math.sin(2*math.pi*i/_sine_len)) for i in range(_sine_len)]

# %%
plt.plot(_sine_buf)

# %%
from scipy.signal import chirp
import numpy as np

# %%
t = np.linspace(0, 10, 5001)
w = chirp(t, f0=1, f1=10, t1=10, method='linear')

# %%
plt.plot(t,w)

# %%
_sine_len = 100 # Number of points in sine wave.
_sine_buf = [128+int(127*math.sin(2*math.pi*i/_sine_len)) for i in range(_sine_len)]

# %%
def chirp(t,f0,f1,t1)
    phase = _chirp_phase(t, f0, t1, f1, method, vertex_zero)
    # Convert  phi to radians.
    phi *= pi / 180
    return cos(phase + phi)


def _chirp_phase(t, f0, t1, f1, method='linear', vertex_zero=True):
    """
    Calculate the phase used by `chirp` to generate its output.
    See `chirp` for a description of the arguments.
    """
    t = asarray(t)
    f0 = float(f0)
    t1 = float(t1)
    f1 = float(f1)
    if method in ['linear', 'lin', 'li']:
        beta = (f1 - f0) / t1

        phase = 2 * pi * (f0 * t + 0.5 * beta * t * t)
# Out:
#   File "<ipython-input-11-b809e0477a7f>", line 11
#     """
#
# ^
# IndentationError: expected an indented block

# %%
plt.plot(_sine_buf)

# %%
f1 = 

_sine_len = 100 # Number of points in sine wave.
_sine_buf = [128+int(127*math.sin(2*math.pi*i/_sine_len)) for i in range(_sine_len)]

# %%
plt.plot([128+int(127*math.sin(2*math.pi*i/_sine_len)) for i in range(_sine_len)])

# %%
f0 = .05
f1 = 50
len_sweep = 1000

beta = 1/math.log(f1/f0)
print(beta)
phase = [ 2*math.pi * beta * f0 * (pow(f1 / f0, i / len_sweep) - 1.0) for i in range(len_sweep)]
#phase = 2 * pi * beta * f0 * (pow(f1 / f0, t / t1) - 1.0)
# Out:
# 0.14476482730108395

# %%
plt.plot(np.cos(phase))
#plt.xlim(0,100)

# %%
# Out:
# 10.0

# %%
t = np.arange(len_sweep)
t1 = len_sweep
beta = t1 / np.log(f1 / f0)
print(beta)
phase = 2 * np.pi * beta * f0 * (pow(f1 / f0, t / t1) - 1.0)
# Out:
# 2556.2221863533146

# %%
plt.plot(np.cos(phase))
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
len_sweep/math.log(f1/f0)
# Out:
# 2556.2221863533146

# %%
            beta = t1 / np.log(f1 / f0)
            phase = 2 * pi * beta * f0 * (pow(f1 / f0, t / t1) - 1.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-4eb1ec947840> in <module>
# ----> 1 beta = t1 / np.log(f1 / f0)
#       2 phase = 2 * pi * beta * f0 * (pow(f1 / f0, t / t1) - 1.0)
#
# NameError: name 't1' is not defined

# %%
plt.plot(np.cos(phase))
#plt.xlim(0,100)
# Out:
# (0, 100)

# %%
plt.plot(chirp(np.arange(len_sweep),f0=f0,f1=f1,t1=len_sweep,method='log'))
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
plt.plot(chirp(np.linspace(0,99,10000)/50.,f0=1,f1=100,t1=1,method='log'))

# %%
aa = np.linspace(0,1,num=10)

# %%
plt.plot()
